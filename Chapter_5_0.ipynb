# %%
# import supporting libraries
import torch
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import requests
from io import BytesIO

# set seed to ensure reproducibility
torch.manual_seed(8)

# %%
url = 'https://raw.githubusercontent.com/jackliu333/regularization_in_deep_learning/main/Image.png'
# initiate an HTTP request via the get method
response = requests.get(url)
# access the content of the response to retrieve the image
img = Image.open(BytesIO(response.content))
# convert to numpy array
img = np.array(img)
# ignore the fourth channel since it's not needed
img = img[...,:3]

plt.imshow(img, interpolation='nearest')
plt.show()

# %%
# specify the data augmentation scheme
img_augment = transforms.Compose([transforms.RandomHorizontalFlip(), # flip the image w.r.t horizontal axis
                                      transforms.RandomRotation(10),     # rotate the image up to 10 degress
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # randomly changes image brightness, contrast and saturation up to a certain degree
                                      transforms.ToTensor() # convert to tensor object to work with torch
                               ])

# %%
import copy 
def gen_img(img):
    # convert to PIL image format using a copied instance
    img2 = transforms.ToPILImage()(copy.copy(img))
    # apply data augmentation
    img2 = img_augment(img2) 
    # move the color channel to the last for plotting purpose
    img2 = np.transpose(img2, (1, 2, 0))
    return img2

fig = plt.figure(figsize=(10, 4)) 

# plot 10 randomly generated images
for idx in np.arange(10):
  ax = fig.add_subplot(2, 5, idx+1, xticks=[], yticks=[]) 
  plt.imshow(gen_img(img)) 
  ax.set_title(idx)

# %% [markdown]
# # Training without data augmentation

# %%
# transformation steps for training and test set upon loading the dataset
transform = transforms.Compose([transforms.ToTensor(), 
                                      transforms.Normalize(mean=(0.5, 0.5, 0.5), 
                                                           std=(0.5, 0.5, 0.5))])
# download the CIFAR10 dataset
training_dataset = datasets.CIFAR10(root='./data', train=True, download=True, 
                                    transform=transform) 
validation_dataset = datasets.CIFAR10(root='./data', train=False, download=True, 
                                      transform=transform)
# define data loader that reads 100 images at a time
training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=100, 
                                              shuffle=True) 
validation_loader = torch.utils.data.DataLoader(validation_dataset, 
                                                batch_size = 100, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# We need to convert the images to numpy arrays as tensors are not compatible with matplotlib.
# format the image for plotting
def convert_tensor_to_np(tensor_img):  
  # convert to numpy
  image = tensor_img.clone().numpy() 
  # move color channel to the last
  image = image.transpose(1, 2, 0)
  # unscale the image back to [0,1]
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
  image = image.clip(0, 1)
  return image

# get some random training images from the first batch
dataiter = iter(training_loader)
images, labels = dataiter.next()
# define the class labels for visualizing purpose
classes = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']
# plot the images in a 2x5 grid
fig = plt.figure(figsize=(10, 4)) 
for idx in np.arange(10):
  ax = fig.add_subplot(2, 5, idx+1, xticks=[], yticks=[]) 
  plt.imshow(convert_tensor_to_np(images[idx]))
  ax.set_title(classes[labels[idx].item()])

# %%
class LeNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, 
                              stride=1, padding=1) 
        # double the depth of feature maps for every conv layer
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1) 
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        # input image is 32*32, after 3 MaxPooling layers it reduces to 4*4 64 feature maps
        self.fc1 = nn.Linear(4*4*64, 500) 
        self.dropout1 = nn.Dropout(0.5)
        # 10 output nodes that map to 10 classes
        self.fc2 = nn.Linear(500, 10) 

    def forward(self, x):
        # apply relu to each conv layer output
        x = F.relu(self.conv1(x)) 
        # max pooling layer with 2x2 kernel to shrink the size by half
        x = F.max_pool2d(x, 2, 2) 
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        # flatten the images as 1D input to the fully connected layer
        x = x.view(-1, 4*4*64) 
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = self.fc2(x)
        return x

# %%
# use GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = LeNet().to(device) 
model
# Out:
# LeNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss() 
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# %%
# %%time

epochs = 100
training_loss_history = []
training_accuracy_history = []
val_loss_history = []
val_accuracy_history = []

for e in range(epochs): 
    training_loss = 0.0
    training_accuracy = 0.0
    val_loss = 0.0
    val_accuracy = 0.0
    # iterate over each batch of training set
    for inputs, labels in training_loader:
        # send to GPU for faster training
        inputs = inputs.to(device) 
        labels = labels.to(device)
        # get logit output
        outputs = model(inputs) 
        # calculate CRE loss
        loss = criterion(outputs, labels) 
        # clear existing gradients
        optimizer.zero_grad() 
        # backpropagate the loss
        loss.backward() 
        # update the weights
        optimizer.step() 
        # take the indexes of maximum logits as class prediction
        _, preds = torch.max(outputs, 1) 
        training_loss += loss.item()
        # count the correct predictions in a batch
        training_accuracy += torch.sum(preds == labels.data) 
    # check validation performance without gradient evaluation
    with torch.no_grad(): 
        for val_inputs, val_labels in validation_loader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device)
            val_outputs = model(val_inputs)
            val_loss_model = criterion(val_outputs, val_labels)
            _, val_preds = torch.max(val_outputs, 1)
            val_loss += val_loss_model.item()
            val_accuracy += torch.sum(val_preds == val_labels.data)
    # average loss per epoch
    epoch_loss = training_loss/len(training_loader) 
    val_epoch_loss = val_loss/len(validation_loader)
    # accuracy per epoch
    epoch_acc = training_accuracy.float()/ len(training_loader) 
    val_epoch_acc = val_accuracy.float()/ len(validation_loader)
    # append to master list for visualization
    training_loss_history.append(epoch_loss) 
    training_accuracy_history.append(epoch_acc.item())
    val_loss_history.append(val_epoch_loss)
    val_accuracy_history.append(val_epoch_acc.item())
    print('Epoch :', (e+1))
    print('Training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
    print('Validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# Epoch : 1
# Training loss: 2.2959, acc 14.2200
# Validation loss: 2.2851, validation acc 15.4100
# Epoch : 2
# Training loss: 2.2062, acc 20.8360
# Validation loss: 2.0465, validation acc 26.9600
# Epoch : 3
# Training loss: 1.9391, acc 29.8500
# Validation loss: 1.8414, validation acc 33.7500
# Epoch : 4
# Training loss: 1.7765, acc 35.6940
# Validation loss: 1.7016, validation acc 37.9900
# Epoch : 5
# Training loss: 1.6563, acc 39.5700
# Validation loss: 1.6063, validation acc 41.3100
# Epoch : 6
# Training loss: 1.5706, acc 42.4260
# Validation loss: 1.5156, validation acc 44.6200
# Epoch : 7
# Training loss: 1.5142, acc 44.6380
# Validation loss: 1.4730, validation acc 46.0600
# Epoch : 8
# Training loss: 1.4642, acc 46.8140
# Validation loss: 1.4273, validation acc 47.5200
# Epoch : 9
# Training loss: 1.4205, acc 48.4960
# Validation loss: 1.3992, validation acc 48.7700
# Epoch : 10
# Training loss: 1.3797, acc 49.9180
# Validation loss: 1.3494, validation acc 50.8400
# Epoch : 11
# Training loss: 1.3478, acc 51.6780
# Validation loss: 1.3512, validation acc 51.3600
# Epoch : 12
# Training loss: 1.3182, acc 52.6600
# Validation loss: 1.2946, validation acc 53.1000
# Epoch : 13
# Training loss: 1.2891, acc 53.8500
# Validation loss: 1.2752, validation acc 54.4000
# Epoch : 14
# Training loss: 1.2623, acc 54.6080
# Validation loss: 1.2574, validation acc 54.2900
# Epoch : 15
# Training loss: 1.2359, acc 55.9520
# Validation loss: 1.2581, validation acc 55.0400
# Epoch : 16
# Training loss: 1.2101, acc 56.8520
# Validation loss: 1.2034, validation acc 56.8500
# Epoch : 17
# Training loss: 1.1859, acc 57.7880
# Validation loss: 1.1968, validation acc 57.0700
# Epoch : 18
# Training loss: 1.1633, acc 58.7260
# Validation loss: 1.1668, validation acc 58.5400
# Epoch : 19
# Training loss: 1.1410, acc 59.3840
# Validation loss: 1.1532, validation acc 58.4100
# Epoch : 20
# Training loss: 1.1154, acc 60.4200
# Validation loss: 1.1383, validation acc 59.5200
# Epoch : 21
# Training loss: 1.0970, acc 61.3340
# Validation loss: 1.1286, validation acc 59.8400
# Epoch : 22
# Training loss: 1.0780, acc 61.7820
# Validation loss: 1.1338, validation acc 59.8700
# Epoch : 23
# Training loss: 1.0578, acc 62.7420
# Validation loss: 1.1484, validation acc 58.7700
# Epoch : 24
# Training loss: 1.0375, acc 63.3860
# Validation loss: 1.0837, validation acc 61.4100
# Epoch : 25
# Training loss: 1.0180, acc 64.2100
# Validation loss: 1.0703, validation acc 62.4200
# Epoch : 26
# Training loss: 1.0043, acc 64.6080
# Validation loss: 1.0558, validation acc 62.5900
# Epoch : 27
# Training loss: 0.9808, acc 65.4400
# Validation loss: 1.0491, validation acc 62.6000
# Epoch : 28
# Training loss: 0.9670, acc 65.9920
# Validation loss: 1.0321, validation acc 63.3900
# Epoch : 29
# Training loss: 0.9433, acc 66.8160
# Validation loss: 1.0455, validation acc 63.1500
# Epoch : 30
# Training loss: 0.9303, acc 67.3820
# Validation loss: 1.0112, validation acc 64.5000
# Epoch : 31
# Training loss: 0.9143, acc 67.8340
# Validation loss: 0.9974, validation acc 65.3300
# Epoch : 32
# Training loss: 0.9001, acc 68.3140
# Validation loss: 0.9838, validation acc 65.8100
# Epoch : 33
# Training loss: 0.8849, acc 68.9800
# Validation loss: 0.9818, validation acc 65.2100
# Epoch : 34
# Training loss: 0.8694, acc 69.5680
# Validation loss: 0.9853, validation acc 65.4800
# Epoch : 35
# Training loss: 0.8544, acc 70.0020
# Validation loss: 0.9804, validation acc 65.8100
# Epoch : 36
# Training loss: 0.8391, acc 70.6320
# Validation loss: 0.9583, validation acc 66.7500
# Epoch : 37
# Training loss: 0.8223, acc 70.9500
# Validation loss: 0.9708, validation acc 66.4900
# Epoch : 38
# Training loss: 0.8084, acc 71.7080
# Validation loss: 0.9532, validation acc 66.7600
# Epoch : 39
# Training loss: 0.7982, acc 71.9960
# Validation loss: 0.9488, validation acc 67.0000
# Epoch : 40
# Training loss: 0.7806, acc 72.6220
# Validation loss: 0.9560, validation acc 66.5200
# Epoch : 41
# Training loss: 0.7687, acc 73.1720
# Validation loss: 0.9518, validation acc 67.1300
# Epoch : 42
# Training loss: 0.7568, acc 73.5180
# Validation loss: 0.9303, validation acc 68.2000
# Epoch : 43
# Training loss: 0.7387, acc 74.0460
# Validation loss: 0.9360, validation acc 67.8000
# Epoch : 44
# Training loss: 0.7267, acc 74.5960
# Validation loss: 0.9164, validation acc 68.3000
# Epoch : 45
# Training loss: 0.7216, acc 74.8260
# Validation loss: 0.9586, validation acc 67.3700
# Epoch : 46
# Training loss: 0.7064, acc 75.3460
# Validation loss: 0.9094, validation acc 69.0500
# Epoch : 47
# Training loss: 0.6965, acc 75.7040
# Validation loss: 0.9245, validation acc 68.7800
# Epoch : 48
# Training loss: 0.6782, acc 76.2960
# Validation loss: 0.9137, validation acc 68.4400
# Epoch : 49
# Training loss: 0.6697, acc 76.5800
# Validation loss: 0.9171, validation acc 68.7700
# Epoch : 50
# Training loss: 0.6593, acc 76.8480
# Validation loss: 0.9278, validation acc 68.7100
# Epoch : 51
# Training loss: 0.6476, acc 77.1540
# Validation loss: 0.9017, validation acc 69.4800
# Epoch : 52
# Training loss: 0.6363, acc 77.5780
# Validation loss: 0.9161, validation acc 69.2600
# Epoch : 53
# Training loss: 0.6257, acc 77.9100
# Validation loss: 0.8943, validation acc 69.9600
# Epoch : 54
# Training loss: 0.6127, acc 78.4300
# Validation loss: 0.9232, validation acc 68.8900
# Epoch : 55
# Training loss: 0.5964, acc 79.0260
# Validation loss: 0.9125, validation acc 69.4000
# Epoch : 56
# Training loss: 0.5901, acc 79.2700
# Validation loss: 0.9223, validation acc 69.9200
# Epoch : 57
# Training loss: 0.5796, acc 79.7540
# Validation loss: 0.9262, validation acc 69.1200
# Epoch : 58
# Training loss: 0.5711, acc 79.9180
# Validation loss: 0.9214, validation acc 69.9100
# Epoch : 59
# Training loss: 0.5586, acc 80.2680
# Validation loss: 0.9376, validation acc 69.4100
# Epoch : 60
# Training loss: 0.5483, acc 80.6660
# Validation loss: 0.9186, validation acc 69.6400
# Epoch : 61
# Training loss: 0.5345, acc 81.1580
# Validation loss: 0.9206, validation acc 70.0200
# Epoch : 62
# Training loss: 0.5277, acc 81.2880
# Validation loss: 0.9200, validation acc 70.1600
# Epoch : 63
# Training loss: 0.5162, acc 81.7000
# Validation loss: 0.9286, validation acc 69.9200
# Epoch : 64
# Training loss: 0.5115, acc 82.0440
# Validation loss: 0.9446, validation acc 69.9600
# Epoch : 65
# Training loss: 0.4979, acc 82.4180
# Validation loss: 0.9345, validation acc 70.1000
# Epoch : 66
# Training loss: 0.4862, acc 82.8420
# Validation loss: 0.9202, validation acc 70.0900
# Epoch : 67
# Training loss: 0.4754, acc 83.2160
# Validation loss: 0.9496, validation acc 70.4100
# Epoch : 68
# Training loss: 0.4683, acc 83.4680
# Validation loss: 0.9519, validation acc 69.9400
# Epoch : 69
# Training loss: 0.4609, acc 83.6740
# Validation loss: 0.9411, validation acc 70.2800
# Epoch : 70
# Training loss: 0.4476, acc 84.3060
# Validation loss: 0.9647, validation acc 70.3000
# Epoch : 71
# Training loss: 0.4388, acc 84.4600
# Validation loss: 0.9597, validation acc 70.5300
# Epoch : 72
# Training loss: 0.4308, acc 84.6200
# Validation loss: 0.9487, validation acc 70.2200
# Epoch : 73
# Training loss: 0.4222, acc 85.0500
# Validation loss: 0.9727, validation acc 70.7400
# Epoch : 74
# Training loss: 0.4096, acc 85.3200
# Validation loss: 1.0074, validation acc 70.2800
# Epoch : 75
# Training loss: 0.4026, acc 85.7000
# Validation loss: 0.9843, validation acc 70.5500
# Epoch : 76
# Training loss: 0.3920, acc 86.1520
# Validation loss: 1.0279, validation acc 69.9100
# Epoch : 77
# Training loss: 0.3828, acc 86.4620
# Validation loss: 1.0013, validation acc 70.2300
# Epoch : 78
# Training loss: 0.3798, acc 86.4840
# Validation loss: 1.0374, validation acc 70.0200
# Epoch : 79
# Training loss: 0.3716, acc 86.6440
# Validation loss: 1.0240, validation acc 70.4700
# Epoch : 80
# Training loss: 0.3665, acc 86.9380
# Validation loss: 1.0450, validation acc 69.5600
# Epoch : 81
# Training loss: 0.3545, acc 87.3820
# Validation loss: 1.0460, validation acc 69.9900
# Epoch : 82
# Training loss: 0.3461, acc 87.7240
# Validation loss: 1.0418, validation acc 70.3200
# Epoch : 83
# Training loss: 0.3417, acc 87.8940
# Validation loss: 1.0545, validation acc 70.0500
# Epoch : 84
# Training loss: 0.3369, acc 88.0180
# Validation loss: 1.0715, validation acc 70.2600
# Epoch : 85
# Training loss: 0.3225, acc 88.5620
# Validation loss: 1.0645, validation acc 70.2900
# Epoch : 86
# Training loss: 0.3158, acc 88.6260
# Validation loss: 1.0813, validation acc 70.2000
# Epoch : 87
# Training loss: 0.3105, acc 88.8520
# Validation loss: 1.0583, validation acc 70.3500
# Epoch : 88
# Training loss: 0.3046, acc 89.2060
# Validation loss: 1.0828, validation acc 70.0900
# Epoch : 89
# Training loss: 0.2952, acc 89.5080
# Validation loss: 1.1178, validation acc 69.8900
# Epoch : 90
# Training loss: 0.2860, acc 89.7080
# Validation loss: 1.1131, validation acc 70.6100
# Epoch : 91
# Training loss: 0.2881, acc 89.6040
# Validation loss: 1.1277, validation acc 69.5100
# Epoch : 92
# Training loss: 0.2785, acc 90.1740
# Validation loss: 1.1024, validation acc 70.1200
# Epoch : 93
# Training loss: 0.2671, acc 90.4900
# Validation loss: 1.1289, validation acc 70.3900
# Epoch : 94
# Training loss: 0.2678, acc 90.2600
# Validation loss: 1.1466, validation acc 69.8800
# Epoch : 95
# Training loss: 0.2631, acc 90.5680
# Validation loss: 1.1353, validation acc 69.9900
# Epoch : 96
# Training loss: 0.2544, acc 90.8900
# Validation loss: 1.1676, validation acc 69.8100
# Epoch : 97
# Training loss: 0.2484, acc 91.0120
# Validation loss: 1.1611, validation acc 69.5900
# Epoch : 98
# Training loss: 0.2441, acc 91.2540
# Validation loss: 1.1763, validation acc 70.8900
# Epoch : 99
# Training loss: 0.2379, acc 91.5300
# Validation loss: 1.2140, validation acc 69.7500
# Epoch : 100
# Training loss: 0.2321, acc 91.7340
# Validation loss: 1.2168, validation acc 69.8600
# CPU times: user 20min 56s, sys: 8.54 s, total: 21min 5s
# Wall time: 20min 59s

# %%
plt.rcParams["figure.figsize"] = (15,6)
fig=plt.figure()
plt.subplot(121)
plt.plot(training_loss_history, label='training loss')
plt.plot(val_loss_history, label='validation loss')
plt.subplot(122)
plt.plot(training_accuracy_history, label='training accuracy')
plt.plot(val_accuracy_history, label='validation accuracy')
plt.legend()

# %% [markdown]
# # Training with data augmentation

# %%
transform_aug = transforms.Compose([
                                    # flip the image w.r.t horizontal axis
                                    transforms.RandomHorizontalFlip(), 
                                    # rotate the image to a specified angel
                                    transforms.RandomRotation(10), 
                                    # zoom and shear
                                    transforms.RandomAffine(0, shear=10, 
                                                            scale=(0.8,1.2)), 
                                    # change color
                                    transforms.ColorJitter(brightness=0.2, 
                                                           contrast=0.2, 
                                                           saturation=0.2), 
                                    transforms.ToTensor(),  
                                    transforms.Normalize((0.5, 0.5, 0.5), 
                                                         (0.5, 0.5, 0.5)) 
                               ])
training_dataset_aug = datasets.CIFAR10(root='./data_aug', train=True, 
                                        download=True, transform=transform_aug) 
training_loader_aug = torch.utils.data.DataLoader(training_dataset_aug, 
                                                  batch_size=100, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data_aug/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data_aug/cifar-10-python.tar.gz to ./data_aug

# %%
model_aug = LeNet().to(device) 
optimizer_aug = torch.optim.SGD(model_aug.parameters(), lr = 0.01)

# %%
# %%time

epochs = 100
training_loss_history_aug = []
training_accuracy_history_aug = []
val_loss_history_aug = []
val_accuracy_history_aug = []

for e in range(epochs): 
    training_loss = 0.0
    training_accuracy = 0.0
    val_loss = 0.0
    val_accuracy = 0.0
    # iterate over each batch of training set
    for inputs, labels in training_loader_aug:
        # send to GPU for faster training
        inputs = inputs.to(device) 
        labels = labels.to(device)
        # get logit output
        outputs = model_aug(inputs) 
        # calculate CRE loss
        loss = criterion(outputs, labels) 
        # clear existing gradients
        optimizer_aug.zero_grad() 
        # backpropagate the loss
        loss.backward() 
        # update the weights
        optimizer_aug.step() 
        # take the indexes of maximum logits as class prediction
        _, preds = torch.max(outputs, 1) 
        training_loss += loss.item()
        # count the correct predictions in a batch
        training_accuracy += torch.sum(preds == labels.data) 
    # check validation performance without gradient evaluation
    with torch.no_grad(): 
        for val_inputs, val_labels in validation_loader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device)
            val_outputs = model_aug(val_inputs)
            val_loss_model = criterion(val_outputs, val_labels)
            _, val_preds = torch.max(val_outputs, 1)
            val_loss += val_loss_model.item()
            val_accuracy += torch.sum(val_preds == val_labels.data)
    # average loss per epoch
    epoch_loss = training_loss/len(training_loader) 
    val_epoch_loss = val_loss/len(validation_loader)
    # accuracy per epoch
    epoch_acc = training_accuracy.float()/ len(training_loader) 
    val_epoch_acc = val_accuracy.float()/ len(validation_loader)
    # append to master list for visualization
    training_loss_history_aug.append(epoch_loss) 
    training_accuracy_history_aug.append(epoch_acc.item())
    val_loss_history_aug.append(val_epoch_loss)
    val_accuracy_history_aug.append(val_epoch_acc.item())
    print('Epoch :', (e+1))
    print('Training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
    print('Validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# Epoch : 1
# Training loss: 2.2967, acc 12.6660
# Validation loss: 2.2847, validation acc 17.8400
# Epoch : 2
# Training loss: 2.2268, acc 19.1020
# Validation loss: 2.1036, validation acc 23.9300
# Epoch : 3
# Training loss: 2.0390, acc 25.3300
# Validation loss: 1.9513, validation acc 29.7400
# Epoch : 4
# Training loss: 1.9299, acc 30.0440
# Validation loss: 1.8437, validation acc 33.5100
# Epoch : 5
# Training loss: 1.8369, acc 33.4280
# Validation loss: 1.7302, validation acc 38.0700
# Epoch : 6
# Training loss: 1.7542, acc 36.4520
# Validation loss: 1.6493, validation acc 39.8700
# Epoch : 7
# Training loss: 1.6841, acc 39.0720
# Validation loss: 1.5935, validation acc 42.1800
# Epoch : 8
# Training loss: 1.6286, acc 41.0840
# Validation loss: 1.5349, validation acc 43.7800
# Epoch : 9
# Training loss: 1.5859, acc 42.6480
# Validation loss: 1.5212, validation acc 44.3000
# Epoch : 10
# Training loss: 1.5496, acc 43.8280
# Validation loss: 1.4742, validation acc 46.0400
# Epoch : 11
# Training loss: 1.5155, acc 45.2020
# Validation loss: 1.4403, validation acc 47.4500
# Epoch : 12
# Training loss: 1.4870, acc 46.4160
# Validation loss: 1.4036, validation acc 49.2900
# Epoch : 13
# Training loss: 1.4607, acc 47.4960
# Validation loss: 1.3812, validation acc 50.4300
# Epoch : 14
# Training loss: 1.4355, acc 48.3420
# Validation loss: 1.3643, validation acc 50.7900
# Epoch : 15
# Training loss: 1.4158, acc 48.9360
# Validation loss: 1.3380, validation acc 51.8700
# Epoch : 16
# Training loss: 1.3901, acc 50.2760
# Validation loss: 1.3117, validation acc 52.7500
# Epoch : 17
# Training loss: 1.3676, acc 50.9840
# Validation loss: 1.2899, validation acc 53.7500
# Epoch : 18
# Training loss: 1.3489, acc 51.9000
# Validation loss: 1.2680, validation acc 54.6300
# Epoch : 19
# Training loss: 1.3315, acc 52.7200
# Validation loss: 1.2377, validation acc 55.6300
# Epoch : 20
# Training loss: 1.3101, acc 53.2880
# Validation loss: 1.2335, validation acc 56.3100
# Epoch : 21
# Training loss: 1.2913, acc 54.2200
# Validation loss: 1.2106, validation acc 56.7300
# Epoch : 22
# Training loss: 1.2750, acc 54.5160
# Validation loss: 1.1910, validation acc 57.0400
# Epoch : 23
# Training loss: 1.2589, acc 55.2720
# Validation loss: 1.1826, validation acc 57.8400
# Epoch : 24
# Training loss: 1.2411, acc 55.8080
# Validation loss: 1.1794, validation acc 58.2400
# Epoch : 25
# Training loss: 1.2237, acc 56.6220
# Validation loss: 1.1720, validation acc 58.2600
# Epoch : 26
# Training loss: 1.2107, acc 57.0960
# Validation loss: 1.1230, validation acc 59.7600
# Epoch : 27
# Training loss: 1.1979, acc 57.5340
# Validation loss: 1.1182, validation acc 60.3300
# Epoch : 28
# Training loss: 1.1842, acc 58.0700
# Validation loss: 1.0913, validation acc 61.0300
# Epoch : 29
# Training loss: 1.1672, acc 58.5880
# Validation loss: 1.0862, validation acc 61.2600
# Epoch : 30
# Training loss: 1.1513, acc 59.3840
# Validation loss: 1.0903, validation acc 61.2600
# Epoch : 31
# Training loss: 1.1411, acc 59.5220
# Validation loss: 1.0755, validation acc 62.0600
# Epoch : 32
# Training loss: 1.1276, acc 60.3100
# Validation loss: 1.0576, validation acc 62.5800
# Epoch : 33
# Training loss: 1.1194, acc 60.4660
# Validation loss: 1.0342, validation acc 63.6000
# Epoch : 34
# Training loss: 1.1041, acc 61.2840
# Validation loss: 1.0487, validation acc 63.3400
# Epoch : 35
# Training loss: 1.0901, acc 61.5080
# Validation loss: 1.0193, validation acc 63.9700
# Epoch : 36
# Training loss: 1.0802, acc 62.0020
# Validation loss: 1.0238, validation acc 64.4100
# Epoch : 37
# Training loss: 1.0684, acc 62.1160
# Validation loss: 1.0008, validation acc 64.7500
# Epoch : 38
# Training loss: 1.0599, acc 62.7600
# Validation loss: 0.9850, validation acc 65.0000
# Epoch : 39
# Training loss: 1.0519, acc 63.1280
# Validation loss: 0.9693, validation acc 66.1500
# Epoch : 40
# Training loss: 1.0400, acc 63.5460
# Validation loss: 0.9812, validation acc 65.2100
# Epoch : 41
# Training loss: 1.0329, acc 63.6320
# Validation loss: 0.9596, validation acc 66.3500
# Epoch : 42
# Training loss: 1.0230, acc 63.7860
# Validation loss: 0.9414, validation acc 67.5800
# Epoch : 43
# Training loss: 1.0149, acc 64.2460
# Validation loss: 0.9442, validation acc 66.6300
# Epoch : 44
# Training loss: 1.0040, acc 64.4600
# Validation loss: 0.9423, validation acc 67.2700
# Epoch : 45
# Training loss: 0.9999, acc 64.7040
# Validation loss: 0.9256, validation acc 67.5900
# Epoch : 46
# Training loss: 0.9868, acc 65.4120
# Validation loss: 0.9239, validation acc 67.6300
# Epoch : 47
# Training loss: 0.9835, acc 65.2780
# Validation loss: 0.9025, validation acc 68.3100
# Epoch : 48
# Training loss: 0.9801, acc 65.5980
# Validation loss: 0.9270, validation acc 67.6700
# Epoch : 49
# Training loss: 0.9692, acc 65.9820
# Validation loss: 0.9249, validation acc 67.6000
# Epoch : 50
# Training loss: 0.9637, acc 66.3260
# Validation loss: 0.8962, validation acc 68.1600
# Epoch : 51
# Training loss: 0.9526, acc 66.6620
# Validation loss: 0.8962, validation acc 68.6300
# Epoch : 52
# Training loss: 0.9451, acc 66.8580
# Validation loss: 0.8934, validation acc 68.9500
# Epoch : 53
# Training loss: 0.9416, acc 66.9080
# Validation loss: 0.8960, validation acc 68.9200
# Epoch : 54
# Training loss: 0.9325, acc 67.2260
# Validation loss: 0.8804, validation acc 69.4400
# Epoch : 55
# Training loss: 0.9294, acc 67.3420
# Validation loss: 0.8704, validation acc 69.9100
# Epoch : 56
# Training loss: 0.9238, acc 67.5780
# Validation loss: 0.8644, validation acc 69.5800
# Epoch : 57
# Training loss: 0.9202, acc 67.6620
# Validation loss: 0.8560, validation acc 70.2000
# Epoch : 58
# Training loss: 0.9103, acc 67.9660
# Validation loss: 0.8589, validation acc 70.0000
# Epoch : 59
# Training loss: 0.9031, acc 68.3360
# Validation loss: 0.8395, validation acc 70.6400
# Epoch : 60
# Training loss: 0.9021, acc 68.4860
# Validation loss: 0.8479, validation acc 70.6100
# Epoch : 61
# Training loss: 0.8937, acc 68.8220
# Validation loss: 0.8367, validation acc 70.8600
# Epoch : 62
# Training loss: 0.8937, acc 68.7600
# Validation loss: 0.8304, validation acc 71.1200
# Epoch : 63
# Training loss: 0.8880, acc 68.9020
# Validation loss: 0.8519, validation acc 70.0400
# Epoch : 64
# Training loss: 0.8761, acc 69.1940
# Validation loss: 0.8323, validation acc 71.3400
# Epoch : 65
# Training loss: 0.8761, acc 69.1860
# Validation loss: 0.8278, validation acc 71.5100
# Epoch : 66
# Training loss: 0.8675, acc 69.6100
# Validation loss: 0.8519, validation acc 70.2500
# Epoch : 67
# Training loss: 0.8610, acc 69.7260
# Validation loss: 0.8219, validation acc 71.1900
# Epoch : 68
# Training loss: 0.8587, acc 69.8520
# Validation loss: 0.8290, validation acc 71.1000
# Epoch : 69
# Training loss: 0.8565, acc 69.8740
# Validation loss: 0.8138, validation acc 71.3800
# Epoch : 70
# Training loss: 0.8565, acc 69.9740
# Validation loss: 0.8094, validation acc 71.5200
# Epoch : 71
# Training loss: 0.8504, acc 70.1100
# Validation loss: 0.8137, validation acc 71.4100
# Epoch : 72
# Training loss: 0.8441, acc 70.5040
# Validation loss: 0.8054, validation acc 71.8300
# Epoch : 73
# Training loss: 0.8380, acc 70.5600
# Validation loss: 0.8080, validation acc 71.6700
# Epoch : 74
# Training loss: 0.8350, acc 70.8520
# Validation loss: 0.8013, validation acc 72.0600
# Epoch : 75
# Training loss: 0.8326, acc 70.7500
# Validation loss: 0.8003, validation acc 72.2800
# Epoch : 76
# Training loss: 0.8251, acc 71.0260
# Validation loss: 0.7866, validation acc 72.4200
# Epoch : 77
# Training loss: 0.8236, acc 71.0460
# Validation loss: 0.7923, validation acc 72.2500
# Epoch : 78
# Training loss: 0.8147, acc 71.5560
# Validation loss: 0.7850, validation acc 72.0200
# Epoch : 79
# Training loss: 0.8200, acc 71.4060
# Validation loss: 0.7897, validation acc 72.5400
# Epoch : 80
# Training loss: 0.8067, acc 71.8200
# Validation loss: 0.7927, validation acc 72.2800
# Epoch : 81
# Training loss: 0.8014, acc 71.8760
# Validation loss: 0.7824, validation acc 72.6600
# Epoch : 82
# Training loss: 0.8030, acc 72.0480
# Validation loss: 0.7803, validation acc 72.9900
# Epoch : 83
# Training loss: 0.7962, acc 72.1580
# Validation loss: 0.7782, validation acc 72.9300
# Epoch : 84
# Training loss: 0.7926, acc 72.3560
# Validation loss: 0.7724, validation acc 73.2300
# Epoch : 85
# Training loss: 0.7917, acc 72.5940
# Validation loss: 0.7733, validation acc 73.1100
# Epoch : 86
# Training loss: 0.7877, acc 72.6240
# Validation loss: 0.7675, validation acc 73.2800
# Epoch : 87
# Training loss: 0.7841, acc 72.6000
# Validation loss: 0.7618, validation acc 73.0800
# Epoch : 88
# Training loss: 0.7828, acc 72.7320
# Validation loss: 0.7737, validation acc 72.8600
# Epoch : 89
# Training loss: 0.7751, acc 73.0120
# Validation loss: 0.7751, validation acc 73.0500
# Epoch : 90
# Training loss: 0.7793, acc 72.6760
# Validation loss: 0.7622, validation acc 73.1400
# Epoch : 91
# Training loss: 0.7687, acc 73.1840
# Validation loss: 0.7667, validation acc 72.7800
# Epoch : 92
# Training loss: 0.7697, acc 73.0700
# Validation loss: 0.7669, validation acc 72.9900
# Epoch : 93
# Training loss: 0.7645, acc 73.1220
# Validation loss: 0.7575, validation acc 73.4700
# Epoch : 94
# Training loss: 0.7625, acc 73.3300
# Validation loss: 0.7585, validation acc 73.4300
# Epoch : 95
# Training loss: 0.7576, acc 73.4660
# Validation loss: 0.7619, validation acc 73.8800
# Epoch : 96
# Training loss: 0.7526, acc 73.7520
# Validation loss: 0.7527, validation acc 74.1200
# Epoch : 97
# Training loss: 0.7539, acc 73.8460
# Validation loss: 0.7402, validation acc 74.1400
# Epoch : 98
# Training loss: 0.7513, acc 73.5520
# Validation loss: 0.7337, validation acc 74.6400
# Epoch : 99
# Training loss: 0.7460, acc 73.8600
# Validation loss: 0.7418, validation acc 74.0600
# Epoch : 100
# Training loss: 0.7440, acc 74.0200
# Validation loss: 0.7406, validation acc 74.8600
# CPU times: user 1h 58s, sys: 18.2 s, total: 1h 1min 17s
# Wall time: 1h 1min 4s

# %%
plt.rcParams["figure.figsize"] = (15,6)
fig=plt.figure()
plt.subplot(121)
plt.plot(training_loss_history_aug, label='training loss')
plt.plot(val_loss_history_aug, label='validation loss')
plt.subplot(122)
plt.plot(training_accuracy_history_aug, label='training accuracy')
plt.plot(val_accuracy_history_aug, label='validation accuracy')
plt.legend()
